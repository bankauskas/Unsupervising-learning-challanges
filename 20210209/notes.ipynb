# %%
import math
import numpy as np
import plotly.graph_objects as go
import plotly.offline as py
from plotly.subplots import make_subplots
import plotly.io as pio
# from plotly.subplots import make_subplots

# or list(range(0,100))
x = np.arange(0, 10, 0.1)

# %%
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=("Linear y-axis", "Logarithmic y-axis"))

fig.add_trace(go.Scatter(x=x, y=x,
                    mode='lines',
                    line=dict(color="#4361ee",width=5),
                    name='x = x'),row=1, col=1)

fig.add_trace(go.Scatter(y=[math.e**i for i in x], x=x,
                    mode='lines',
                    line=dict(color="#3CAAE3",width=5),
                    name='x=e**x'),row=1, col=1)

fig.add_trace(go.Scatter(x=x, y=x,
                    mode='lines',
                    line=dict(color="#4361ee",width=5),
                    name='x = x'),row=1, col=2)

fig.add_trace(go.Scatter(y=[math.e**i for i in x], x=x,
                    mode='lines',
                    line=dict(color="#3CAAE3",width=5),
                    name='x=e**x'),row=1, col=2)



fig.update_yaxes(
    range=[0,100], 
    showgrid=False,
    showline=True, linewidth=1, linecolor='white',
    row=1, col=1)

fig.update_xaxes(
    showticklabels=False,
    showgrid=False,
    dtick=False,
    showline=True, linewidth=1, linecolor='white',
    row=1, col=1)

fig.update_yaxes(
    type='log',
    range=[-2,2], 
    showgrid=False,
    showline=True, linewidth=1, linecolor='white',
    row=1, col=2)

fig.update_xaxes(
    showticklabels=False,
    showgrid=False,
    dtick=False,
    showline=True, linewidth=1, linecolor='white',
    row=1, col=2)

fig.update_layout(showlegend=False)


fig.update_layout(height=600, width=1200, title_text="Unsupervising learning challanges. Day:20210209")
fig.show()

# %%
help(fig.update_xaxes())
# Out:
# ble to display LaTeX typesetting as long as internet access
#  |          is available.
#  |
#  |          If a string that ends in '.js', a script tag is included that
#  |          references the specified path. This approach can be used to point the
#  |          resulting HTML div string to an alternative CDN.
#  |      post_script: str or list or None (default None)
#  |          JavaScript snippet(s) to be included in the resulting div just after
#  |          plot creation.  The string(s) may include '{plot_id}' placeholders
#  |          that will then be replaced by the `id` of the div element that the
#  |          plotly.js figure is associated with.  One application for this script
#  |          is to install custom plotly.js event handlers.
#  |      full_html: bool (default True)
#  |          If True, produce a string containing a complete HTML document
#  |          starting with an <html> tag.  If False, produce a string containing
# ...
